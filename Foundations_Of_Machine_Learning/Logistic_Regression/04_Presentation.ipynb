# %% [markdown]
# # Foundations of Machine Learning Series
#
# ## Life Expectancy

# %%
# imports

from IPython.display import Image

import pandas as pd
import pickle
import statsmodels.api as sm

# %%
# constants

PREPARATION_PATH='data/preparation/'
PRESENTATION_PATH='data/presentation/'
INITIAL_FILENAME='data/initial/framingham.csv'

# %% [markdown]
# ## The Dataset
#
# Kaggles WHO Heart Disease Dataset

# %%
# load

df = pd.read_csv(INITIAL_FILENAME)

df.head()
# Out:
#    male  age  education  currentSmoker  cigsPerDay  BPMeds  prevalentStroke  \
# 0     1   39        4.0              0         0.0     0.0                0
# 1     0   46        2.0              0         0.0     0.0                0
# 2     1   48        1.0              1        20.0     0.0                0
# 3     0   61        3.0              1        30.0     0.0                0
# 4     0   46        3.0              1        23.0     0.0                0
#
#    prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  heartRate  glucose  \
# 0             0         0    195.0  106.0   70.0  26.97       80.0     77.0
# 1             0         0    250.0  121.0   81.0  28.73       95.0     76.0
# 2             0         0    245.0  127.5   80.0  25.34       75.0     70.0
# 3             1         0    225.0  150.0   95.0  28.58       65.0    103.0
# 4             0         0    285.0  130.0   84.0  23.10       85.0     85.0
#
#    TenYearCHD
# 0           0
# 1           0
# ...

# %% [markdown]
# After processing by eliminating null values and handling outliers here is the distribution of data.

# %%
Image(PRESENTATION_PATH + 'Distribution of Columns.png')

# %%
Image(PRESENTATION_PATH + 'Distribution of Columns vs TenYearCHD.png')

# %%
Image(PRESENTATION_PATH + 'Correlation Matrix of Numerical Variables.png')

# %% [markdown]
# From there I narrowed down the columns to
#     'age',
#     'education',
#     'currentSmoker',
#     'prevalentHyp',
#     'sysBP',
#     'BMI',
#     'heartRate',
#     'TenYearCHD'

# %% [markdown]
# Something to be aware of here is that the target variable has a skewed distribution.

# %%
Image(PRESENTATION_PATH + 'distributionTenYearCHD.png')

# %% [markdown]
# ## Results
#
# Below is the resulting Logistic Regression model results. The original data is highly skewed toward 0, so I used SMOTE to balance the training dataset, which prevented nearly all predicted values from being 0.

# %%
Image(PRESENTATION_PATH + 'confusion_matrix.png')

# %% [markdown]
# The results are not perfect by any means. The model here has many false positives, but given the context here it is important not to predict 0 when the subject may actually be at risk for coronary heart disease.
